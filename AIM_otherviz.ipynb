# %%
import pandas as pd
import numpy as np
import plotly 
import cufflinks as cf
import wbpy
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
plotly.tools.set_credentials_file(username='richongo', api_key='knfESm6zSffWin5ujtln')
import matplotlib.pyplot as plt
import scipy.stats as stats
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Import Aid data
file1 = "Economic_vs_Military.xlsx"
Aid_df = pd.read_excel(file1)
file2= "InfantMorality.csv"
Aid_df = Aid_df.rename(columns={"Row Labels": "Country"})
InfantMortality_df = pd.read_csv(file2)

InfantMortality_df.head()
# Out:
#    Unnamed: 0  Year   Angola  Burundi    Benin  Ethiopia    Ghana    Kenya  \
# 0           0  2002  95971.0  24984.0  25051.0  236821.0  41281.0  75705.0
# 1           1  2003  95253.0  24759.0  24920.0  227584.0  40940.0  73661.0
# 2           2  2004  93986.0  24537.0  24813.0  217766.0  40789.0  71278.0
# 3           3  2005  92430.0  24267.0  24755.0  207679.0  40758.0  68408.0
# 4           4  2006  90346.0  23937.0  24793.0  198004.0  40772.0  65861.0
#
#    Madagascar     Mali  Mozambique  Namibia   Nigeria   Rwanda  Senegal  \
# 0     40879.0  59444.0     85134.0   2804.0  568287.0  29228.0  25026.0
# 1     39524.0  58812.0     82977.0   2780.0  564928.0  27352.0  24344.0
# 2     38252.0  58033.0     80906.0   2724.0  560267.0  25200.0  23665.0
# 3     37048.0  57135.0     78926.0   2559.0  554716.0  23209.0  23032.0
# 4     35925.0  56376.0     76947.0   2461.0  548359.0  21394.0  22467.0
#
#    Sierra Leone  Somalia   Uganda  South Africa  Zimbabwe
# 0       29723.0  46562.0  98596.0       59495.0   23990.0
# 1       29885.0  47551.0  96119.0       59666.0   24394.0
# 2       29984.0  48604.0  93242.0       59263.0   25221.0
# 3       29984.0  49701.0  90154.0       58548.0   26068.0
# 4       29798.0  50689.0  87169.0       57132.0   27209.0

# %%
api = wbpy.IndicatorAPI()

iso_country_codes = ["KEN", "ZAF", "NGA", "ZWE", "ETH", "UGA",
                     "GHA", "SEN", "MDG", "MOZ", "NAM", "BDI",
                    "BEN", "SOM", "MLI", "AGO", "SLE", "RWA"]

infant_mortality = "SH.DTH.IMRT"

dataset_IMRT = api.get_dataset(infant_mortality, iso_country_codes, date="2002:2017")
dataset_IMRT
# Out:
# <wbpy.indicators.IndicatorDataset('SH.DTH.IMRT', 'Number of infant deaths') with id: 2628841021168>

# %%
d=dataset_IMRT.as_dict() 
infant_mortality_df=pd.DataFrame(data=d)
infant_mortality_df
infant_mortality_df = infant_mortality_df.rename(columns={"AO":"Angola", "BI": "Burundi", "BJ": "Benin", "ET":"Ethiopia", "GH": "Ghana", "KE":"Kenya", "MG": "Madagascar", "ML":"Mali", "MZ":"Mozambique",  "NA": "Namibia", "NG":"Nigeria", "RW":"Rwanda", "SN": "Senegal", "SL":"Sierra Leone", "SO": "Somalia", "UG":"Uganda", "ZA":"South Africa", "ZW":"Zimbabwe"})
infant_mortality_df = infant_mortality_df.reset_index()
infant_mortality_df = infant_mortality_df.rename(columns={"index":"Year"})
infant_mortality_df.head
# Out:
# <bound method NDFrame.head of     Year   Angola  Burundi    Benin  Ethiopia    Ghana    Kenya  Madagascar  \
# 0   2002  95971.0  24984.0  25051.0  236821.0  41281.0  75705.0     40879.0
# 1   2003  95253.0  24759.0  24920.0  227584.0  40940.0  73661.0     39524.0
# 2   2004  93986.0  24537.0  24813.0  217766.0  40789.0  71278.0     38252.0
# 3   2005  92430.0  24267.0  24755.0  207679.0  40758.0  68408.0     37048.0
# 4   2006  90346.0  23937.0  24793.0  198004.0  40772.0  65861.0     35925.0
# 5   2007  87956.0  23534.0  24901.0  189064.0  40712.0  63637.0     34801.0
# 6   2008  85249.0  23068.0  25086.0  180863.0  40498.0  60970.0     33681.0
# 7   2009  82217.0  22576.0  25313.0  173475.0  40037.0  59177.0     32601.0
# 8   2010  79220.0  22090.0  25560.0  166949.0  39274.0  57429.0     31536.0
# 9   2011  76226.0  21596.0  25785.0  161040.0  38342.0  56255.0     30498.0
# 10  2012  73448.0  21071.0  25948.0  155642.0  37260.0  55733.0     29580.0
# 11  2013  70939.0  20582.0  26014.0  150446.0  36068.0  54694.0     28857.0
# 12  2014  68913.0  20085.0  25993.0  145625.0  34767.0  53499.0     28296.0
# 13  2015  67337.0  19683.0  25886.0  141119.0  33472.0  52151.0     27871.0
# 14  2016  65993.0  19343.0  25744.0  136965.0  32266.0  51524.0     27472.0
# 15  2017  65045.0  19045.0  25561.0  133153.0  31153.0  51053.0     27165.0
#
#        Mali  Mozambique  Namibia   Nigeria   Rwanda  Senegal  Sierra Leone  \
# 0   59444.0     85134.0   2804.0  568287.0  29228.0  25026.0       29723.0
# 1   58812.0     82977.0   2780.0  564928.0  27352.0  24344.0       29885.0
# 2   58033.0     80906.0   2724.0  560267.0  25200.0  23665.0       29984.0
# 3   57135.0     78926.0   2559.0  554716.0  23209.0  23032.0       29984.0
# 4   56376.0     76947.0   2461.0  548359.0  21394.0  22467.0       29798.0
# 5   55702.0     74209.0   2419.0  541470.0  19749.0  21972.0       29424.0
# 6   55131.0     72452.0   2432.0  534525.0  18350.0  21537.0       28846.0
# 7   54554.0     70380.0   2505.0  527344.0  17111.0  21148.0       28060.0
# 8   53953.0     69718.0   2473.0  520087.0  15931.0  20772.0       27164.0
# 9   53441.0     67191.0   2509.0  512805.0  14575.0  20409.0       26153.0
# 10  52862.0     65093.0   2586.0  504876.0  13594.0  20010.0       25143.0
# 11  52373.0     63604.0   2547.0  497427.0  12763.0  19576.0       24156.0
# 12  51935.0     62706.0   2526.0  490035.0  12093.0  19142.0       23211.0
# 13  51443.0     61823.0   2468.0  481720.0  11555.0  18707.0       22349.0
# 14  50871.0     61004.0   2337.0  473758.0  11082.0  18312.0       21597.0
# 15  50492.0     60047.0   2292.0  465681.0  10677.0  17950.0       20935.0
#
#     Somalia   Uganda  South Africa  Zimbabwe
# 0   46562.0  98596.0       59495.0   23990.0
# 1   47551.0  96119.0       59666.0   24394.0
# 2   48604.0  93242.0       59263.0   25221.0
# 3   49701.0  90154.0       58548.0   26068.0
# 4   50689.0  87169.0       57132.0   27209.0
# 5   51337.0  84191.0       53669.0   27925.0
# 6   51583.0  81316.0       51213.0   28188.0
# 7   51667.0  79262.0       46360.0   28125.0
# 8   51521.0  76848.0       44405.0   27549.0
# 9   51167.0  74379.0       43252.0   26649.0
# 10  50913.0  71165.0       42110.0   25109.0
# 11  50572.0  69216.0       39929.0   23819.0
# 12  50325.0  67569.0       38049.0   22377.0
# 13  50105.0  65764.0       37261.0   21332.0
# 14  49887.0  63831.0       35010.0   20302.0
# 15  49554.0  62416.0       33536.0   19375.0  >

# %%
Infant_Mortality = InfantMortality_df.drop(columns=["Unnamed: 0"])
Infant_Mortality.head()
# Out:
#    Year   Angola  Burundi    Benin  Ethiopia    Ghana    Kenya  Madagascar  \
# 0  2002  95971.0  24984.0  25051.0  236821.0  41281.0  75705.0     40879.0
# 1  2003  95253.0  24759.0  24920.0  227584.0  40940.0  73661.0     39524.0
# 2  2004  93986.0  24537.0  24813.0  217766.0  40789.0  71278.0     38252.0
# 3  2005  92430.0  24267.0  24755.0  207679.0  40758.0  68408.0     37048.0
# 4  2006  90346.0  23937.0  24793.0  198004.0  40772.0  65861.0     35925.0
#
#       Mali  Mozambique  Namibia   Nigeria   Rwanda  Senegal  Sierra Leone  \
# 0  59444.0     85134.0   2804.0  568287.0  29228.0  25026.0       29723.0
# 1  58812.0     82977.0   2780.0  564928.0  27352.0  24344.0       29885.0
# 2  58033.0     80906.0   2724.0  560267.0  25200.0  23665.0       29984.0
# 3  57135.0     78926.0   2559.0  554716.0  23209.0  23032.0       29984.0
# 4  56376.0     76947.0   2461.0  548359.0  21394.0  22467.0       29798.0
#
#    Somalia   Uganda  South Africa  Zimbabwe
# 0  46562.0  98596.0       59495.0   23990.0
# 1  47551.0  96119.0       59666.0   24394.0
# 2  48604.0  93242.0       59263.0   25221.0
# 3  49701.0  90154.0       58548.0   26068.0
# 4  50689.0  87169.0       57132.0   27209.0

# %%
InfantMortality_melt=Infant_Mortality.melt(id_vars=["Year"],
                                              var_name="Country",
                                              value_name="Infant Mortality")
InfantMortality_melt.head(10)
# Out:
#    Year Country  Infant Mortality
# 0  2002  Angola           95971.0
# 1  2003  Angola           95253.0
# 2  2004  Angola           93986.0
# 3  2005  Angola           92430.0
# 4  2006  Angola           90346.0
# 5  2007  Angola           87956.0
# 6  2008  Angola           85249.0
# 7  2009  Angola           82217.0
# 8  2010  Angola           79220.0
# 9  2011  Angola           76226.0

# %%
combined_data=pd.merge(Aid_df, InfantMortality_melt, on=["Country", "Year"])
combined_data.head()
# Out:
#   Country  Year      Economic       Military   Grand Total  Infant Mortality
# 0  Angola  2002  1.659227e+08       0.000000  1.659227e+08           95971.0
# 1  Angola  2003  2.155944e+08  395057.529807  2.159894e+08           95253.0
# 2  Angola  2004  1.520490e+08  638258.217553  1.526873e+08           93986.0
# 3  Angola  2005  8.311513e+07  387385.061877  8.350252e+07           92430.0
# 4  Angola  2006  9.623060e+07  768343.338990  9.699894e+07           90346.0

# %%
CombinedAid_InfantMortality= combined_data.rename(index=str, columns={"Grand Total": "Total Aid"})

# %%
# Group by country and shift two years ahead to see whether there is any impact. 
CombinedAid_InfantMortality_EM2=CombinedAid_InfantMortality.copy()
CombinedAid_InfantMortality_EM2[['Economic_2', 'Military_2']] = CombinedAid_InfantMortality.groupby(['Country'])['Economic', 'Military'].shift(2)
CombinedAid_InfantMortality_EM2= CombinedAid_InfantMortality_EM2.dropna()

# Group by country; shift four years ahead to see effect
CombinedAid_InfantMortality_EM4=CombinedAid_InfantMortality.copy()
CombinedAid_InfantMortality_EM4[['Economic_4', 'Military_4']] = CombinedAid_InfantMortality.groupby(['Country'])['Economic', 'Military'].shift(4)
CombinedAid_InfantMortality_EM4= CombinedAid_InfantMortality_EM4.dropna()

# Repeat for 6-year impact
CombinedAid_InfantMortality_EM6=CombinedAid_InfantMortality.copy()
CombinedAid_InfantMortality_EM6[['Economic_6', 'Military_6']] = CombinedAid_InfantMortality.groupby(['Country'])['Economic', 'Military'].shift(6)
CombinedAid_InfantMortality_EM6= CombinedAid_InfantMortality_EM6.dropna()

CombinedAid_InfantMortality_EM6.head()
# Out:
#    Country  Year      Economic       Military     Total Aid  Infant Mortality  \
# 6   Angola  2008  6.537215e+07  396706.828528  6.576886e+07           85249.0
# 7   Angola  2009  6.095525e+07  535667.400000  6.149092e+07           82217.0
# 8   Angola  2010  1.114652e+08  417850.218081  1.118831e+08           79220.0
# 9   Angola  2011  8.945588e+07  458935.004372  8.991482e+07           76226.0
# 10  Angola  2012  7.950237e+07  468601.717393  7.997097e+07           73448.0
#
#       Economic_6     Military_6
# 6   1.659227e+08       0.000000
# 7   2.155944e+08  395057.529807
# 8   1.520490e+08  638258.217553
# 9   8.311513e+07  387385.061877
# 10  9.623060e+07  768343.338990

# %%
#Isolate Angola, Benin
AngolaAIM=CombinedAid_InfantMortality.loc[CombinedAid_InfantMortality["Country"]=="Angola", :]
BeninAIM=CombinedAid_InfantMortality.loc[CombinedAid_InfantMortality["Country"]=="Benin", :]
BurundiAIM=CombinedAid_InfantMortality.loc[CombinedAid_InfantMortality["Country"]=="Burundi", :]

#Rename for lag
AngolaAIM_2 = AngolaAIM.rename(index=str, columns={"Economic": "Economic_2", "Military": "Military_2"})
AngolaAIM_4 = AngolaAIM.rename(index=str, columns={"Economic": "Economic_4", "Military": "Military_4"})
AngolaAIM_6 = AngolaAIM.rename(index=str, columns={"Economic": "Economic_6", "Military": "Military_6"})

BeninAIM_2 = BeninAIM.rename(index=str, columns={"Economic": "Economic_2", "Military": "Military_2"})
BeninAIM_4 = BeninAIM.rename(index=str, columns={"Economic": "Economic_4", "Military": "Military_4"})
BeninAIM_6 = BeninAIM.rename(index=str, columns={"Economic": "Economic_6", "Military": "Military_6"})

BurundiAIM_2 = BurundiAIM.rename(index=str, columns={"Economic": "Economic_2", "Military": "Military_2"})
BurundiAIM_4 = BurundiAIM.rename(index=str, columns={"Economic": "Economic_4", "Military": "Military_4"})
BurundiAIM_6 = BurundiAIM.rename(index=str, columns={"Economic": "Economic_6", "Military": "Military_6"})

#Add two years to infant mortality
AngolaAIM_2['InfantMortality_2'] = AngolaAIM_2['Economic_2'].shift(-2)
AngolaAIM_2= AngolaAIM_2.dropna()

BeninAIM_2['InfantMortality_2'] = BeninAIM_2['Economic_2'].shift(-2)
BeninAIM_2= BeninAIM_2.dropna()

BurundiAIM_2['InfantMortality_2'] = BurundiAIM_2['Economic_2'].shift(-2)
BurundiAIM_2= BurundiAIM_2.dropna()

##Scatter Economic vs Infant Mortality for Year on Year 
AngolaAIM_scatter=plt.scatter(AngolaAIM['Economic'], AngolaAIM['Infant Mortality'], color='red')
BeninAIM_scatter=plt.scatter(BeninAIM['Economic'], BeninAIM['Infant Mortality'], color='blue')
plt.title('Economic Aid vs Infant Mortality - Year to Year in Angola and Benin', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

#Scatter Economic vs Infant Mortality for funding 2 years after 
plt.scatter(AngolaAIM_2['Economic_2'], AngolaAIM_2['Infant Mortality'], color='red')
plt.scatter(BeninAIM_2['Economic_2'], BeninAIM_2['Infant Mortality'], color='blue')
plt.title('Economic Aid vs Infant Mortality - 2 Years After Funding', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

# %%
#Renaming the file as it will include 2 year lag in InfantMortality Rate
Combined_Aid_InfantMortality_S2 = Combined_Aid_InfantMortality.rename(index=str, columns={"Infant Mortality": "Infant Mortality_2"})
Combined_Aid_InfantMortality_S4 = Combined_Aid_InfantMortality.rename(index=str, columns={"Infant Mortality": "Infant Mortality_4"})
Combined_Aid_InfantMortality_S6 = Combined_Aid_InfantMortality.rename(index=str, columns={"Infant Mortality": "Infant Mortality_6"})
#adding two years to see effect
Combined_Aid_Stability_S2['Total Stability_2'] = Combined_Aid_Stability_S2['Total Stability_2'].shift(-2)
Combined_Aid_Stability_S2= Combined_Aid_Stability_S2.dropna()
#adding four years to see effect
Combined_Aid_Stability_S4['Total Stability_4'] = Combined_Aid_Stability_S4['Total Stability_4'].shift(-4)
Combined_Aid_Stability_S4= Combined_Aid_Stability_S4.dropna()
#adding six years to see effect
Combined_Aid_Stability_S6['Total Stability_6'] = Combined_Aid_Stability_S6['Total Stability_6'].shift(-6)
Combined_Aid_Stability_S6= Combined_Aid_Stability_S6.dropna()

# %%
##Scatter Economic vs Infant Mortality for Year on Year 
plt.scatter(CombinedAid_InfantMortality['Economic'], 
            CombinedAid_InfantMortality['Infant Mortality'], 
            color='red')
plt.title('Economic Aid vs Infant Mortality - Year to Year', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

#Scatter Economic vs Infant Mortality for funding 2 years after 
plt.scatter(CombinedAid_InfantMortality_2['Economic_2'], 
            CombinedAid_InfantMortality_2['Infant Mortality'], 
            color='red')
plt.title('Economic Aid vs Infant Mortality - Funding 2 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

#Scatter Economic vs Infant Mortality for funding 4 years after 
plt.scatter(CombinedAid_InfantMortality_4['Economic_4'], 
            CombinedAid_InfantMortality_4['Infant Mortality'], 
            color='red')
plt.title('Economic Aid vs Infant Mortality - Funding 4 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

#Scatter Economic vs Infant Mortality for funding 6 years after 
plt.scatter(CombinedAid_InfantMortality_6['Economic_6'], 
            CombinedAid_InfantMortality_6['Infant Mortality'], 
            color='red')
plt.title('Economic Aid vs Infant Mortality - Funding 6 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

#Scatter Military vs Infant Mortality for funding on Year
plt.scatter(CombinedAid_InfantMortality['Military'], 
            CombinedAid_InfantMortality['Infant Mortality'], 
            color='green')
plt.title('Military Aid vs Infant Mortality - Year to Year', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

#Scatter Military vs Infant Mortality for funding 2 years after
plt.scatter(CombinedAid_InfantMortality_2['Military_2'], 
            CombinedAid_InfantMortality_2['Infant Mortality'], color='green')
plt.title('Military Aid vs Infant Mortality - Funding 2 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

#Scatter Military vs Infant Mortality for funding 4 years after
plt.scatter(CombinedAid_InfantMortality_4['Military_4'], 
            CombinedAid_InfantMortality_4['Infant Mortality'], 
            color='green')
plt.title('Military Aid vs Infant Mortality - Funding 4 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()

#Scatter Military vs Infant Mortality for funding 6 years after
plt.scatter(CombinedAid_InfantMortality_6['Military_6'], 
            CombinedAid_InfantMortality_6['Infant Mortality'], 
            color='green')
plt.title('Military Aid vs Infant Mortality - Funding 6 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Infant Mortality', fontsize=14)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-7ef4e1a80a26> in <module>
#      10
#      11 #Scatter Economic vs Infant Mortality for funding 2 years after
# ---> 12 plt.scatter(CombinedAid_InfantMortality_2['Economic_2'],
#      13             CombinedAid_InfantMortality_2['Infant Mortality'],
#      14             color='red')
#
# NameError: name 'CombinedAid_InfantMortality_2' is not defined
