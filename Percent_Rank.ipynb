# %%
import wbpy
import pandas as pd

# %%
api = wbpy.IndicatorAPI()

# %%
api = wbpy.IndicatorAPI()

iso_country_codes = ["KEN", "ZAF", "NGA", "ZWE", "ETH", "UGA",
                     "GHA", "SEN", "MDG", "MOZ", "NAM", "BDI",
                    "BEN", "SOM", "MLI", "AGO", "SLE", "RWA"]
stability = "PV.PER.RNK"

dataset_PER_RNK = api.get_dataset(stability, iso_country_codes, date="2002:2017")
dataset_PER_RNK
# Out:
# <wbpy.indicators.IndicatorDataset('PV.PER.RNK', 'Political Stability and Absence of Violence/Terrorism: Percentile Rank') with id: 3189411951000>

# %%
d2=dataset_PER_RNK.as_dict()

# %%
stabilityrank2_df=pd.DataFrame(data=d2)

# %%
stabilityrank2_df
# Out:
#              AO         BI        BJ         ET        GH         KE  \
# 2002   9.523809   0.529100  73.54498  14.814810  40.74074  17.460320
# 2003  19.597990   1.507538  69.34673  10.050250  42.21106  13.567840
# 2004  16.504850   0.970874  54.36893  11.650490  47.08738  16.019420
# 2005  21.359220   6.796116  59.70874   5.825243  51.94175  12.621360
# 2006  27.536230   9.178744  63.28502   7.246377  46.37681  15.942030
# 2007  24.154590   9.661836  57.97102   6.763285  40.57971  11.111110
# 2008  31.250000   9.134615  56.73077   8.653846  43.75000  10.096150
# 2009  32.701420  12.796210  60.18958   6.635071  45.49763   9.478673
# 2010  37.914690   6.635071  53.55450   5.687204  46.91943  12.796210
# 2011  34.597160   4.739336  57.34597   6.161138  52.60664  12.796210
# 2012  35.071090   5.687204  58.29384   7.109005  50.71090  10.426540
# 2013  35.071090   8.530806  58.29384   8.056872  47.86730  13.744080
# 2014  32.857140  20.476190  47.14286   8.571428  41.42857   9.047619
# ...
