# %%
import pandas as pd
import numpy as np
import wbpy
import plotly 
import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
plotly.tools.set_credentials_file(username='richongo', api_key='knfESm6zSffWin5ujtln')
import matplotlib.pyplot as plt
import scipy.stats as stats
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Create two files that will be imported
file1 = "Economic_vs_Military.xlsx"
file2 = "StabilityScore.csv"

#read both files
Stability_df = pd.read_csv(file2)
Aid_df = pd.read_excel(file1)

#show Aid data
Aid_df.head()
# Out:
#   Row Labels  Year      Economic       Military   Grand Total
# 0     Angola  2002  1.659227e+08       0.000000  1.659227e+08
# 1     Angola  2003  2.155944e+08  395057.529807  2.159894e+08
# 2     Angola  2004  1.520490e+08  638258.217553  1.526873e+08
# 3     Angola  2005  8.311513e+07  387385.061877  8.350252e+07
# 4     Angola  2006  9.623060e+07  768343.338990  9.699894e+07

# %%
#rename Row Labels column into Country
Aid_df = Aid_df.rename(columns={"Row Labels": "Country"})
Aid_df.head(10)
# Out:
#   Country  Year      Economic       Military   Grand Total
# 0  Angola  2002  1.659227e+08       0.000000  1.659227e+08
# 1  Angola  2003  2.155944e+08  395057.529807  2.159894e+08
# 2  Angola  2004  1.520490e+08  638258.217553  1.526873e+08
# 3  Angola  2005  8.311513e+07  387385.061877  8.350252e+07
# 4  Angola  2006  9.623060e+07  768343.338990  9.699894e+07
# 5  Angola  2007  6.191552e+07  512302.664188  6.242783e+07
# 6  Angola  2008  6.537215e+07  396706.828528  6.576886e+07
# 7  Angola  2009  6.095525e+07  535667.400000  6.149092e+07
# 8  Angola  2010  1.114652e+08  417850.218081  1.118831e+08
# 9  Angola  2011  8.945588e+07  458935.004372  8.991482e+07

# %%
#check that all countries are there
Aid_df['Country'].value_counts()
# Out:
# Nigeria         16
# Senegal         16
# Madagascar      16
# Benin           16
# Mali            16
# Burundi         16
# Ethiopia        16
# Ghana           16
# Somalia         16
# Kenya           16
# Uganda          16
# Namibia         16
# Zimbabwe        16
# Rwanda          16
# South Africa    16
# Angola          16
# Sierra Leone    16
# Mozambique      16
# Name: Country, dtype: int64

# %%
#show Stability data
Stability_df.head()
# Out:
#    Unnamed: 0        AO        BI        BJ        ET        GH        KE  \
# 0        2002 -1.577046 -2.288240  0.820294 -1.223214 -0.163768 -1.186471
# 1        2003 -1.006538 -2.244527  0.679064 -1.408554  0.028774 -1.262862
# 2        2004 -1.062798 -2.523785  0.265107 -1.311482  0.039967 -1.086909
# 3        2005 -0.887544 -1.524742  0.446816 -1.690749  0.168321 -1.249828
# 4        2006 -0.541986 -1.427005  0.547010 -1.738937  0.008032 -1.125182
#
#          MG        ML        MZ        NA        NG        RW        SN  \
# 0 -0.230007  0.410803  0.186406  0.145299 -1.625118 -1.653260 -0.274071
# 1  0.621700  0.258126  0.246201  0.477721 -1.633998 -1.112363 -0.249980
# 2  0.244328  0.453275  0.002372  0.664466 -1.753987 -1.187092  0.028721
# 3 -0.021505  0.175682  0.124558  0.625277 -1.667195 -1.002252 -0.204454
# 4  0.183486  0.413544  0.519501  0.782987 -2.034141 -0.682115 -0.264090
#
#          SL        SO        UG        ZA        ZW
# 0 -0.688648 -2.375751 -1.418792 -0.253671 -1.521978
# 1 -1.080389 -2.575844 -1.561003 -0.311745 -1.088343
# 2 -0.513328 -2.880443 -1.305026 -0.131361 -1.207500
# 3 -0.479250 -2.709518 -1.417637 -0.162605 -1.272914
# 4 -0.302184 -2.748559 -1.140198  0.048197 -0.932961

# %%
#renaming the codes into countries
Stability_df = Stability_df.rename(columns={"AO":"Angola", "BI": "Burundi", "BJ": "Benin", "ET":"Ethiopia", "GH": "Ghana", "KE":"Kenya", "MG": "Madagascar", "ML":"Mali", "MZ":"Mozambique",  "NA": "Namibia", "NG":"Nigeria", "RW":"Rwanda", "SN": "Senegal", "SL":"Sierra Leone", "SO": "Somalia", "UG":"Uganda", "ZA":"South Africa", "ZW":"Zimbabwe"})
Stability_df.head()
# Out:
#    Unnamed: 0    Angola   Burundi     Benin  Ethiopia     Ghana     Kenya  \
# 0        2002 -1.577046 -2.288240  0.820294 -1.223214 -0.163768 -1.186471
# 1        2003 -1.006538 -2.244527  0.679064 -1.408554  0.028774 -1.262862
# 2        2004 -1.062798 -2.523785  0.265107 -1.311482  0.039967 -1.086909
# 3        2005 -0.887544 -1.524742  0.446816 -1.690749  0.168321 -1.249828
# 4        2006 -0.541986 -1.427005  0.547010 -1.738937  0.008032 -1.125182
#
#    Madagascar      Mali  Mozambique   Namibia   Nigeria    Rwanda   Senegal  \
# 0   -0.230007  0.410803    0.186406  0.145299 -1.625118 -1.653260 -0.274071
# 1    0.621700  0.258126    0.246201  0.477721 -1.633998 -1.112363 -0.249980
# 2    0.244328  0.453275    0.002372  0.664466 -1.753987 -1.187092  0.028721
# 3   -0.021505  0.175682    0.124558  0.625277 -1.667195 -1.002252 -0.204454
# 4    0.183486  0.413544    0.519501  0.782987 -2.034141 -0.682115 -0.264090
#
#    Sierra Leone   Somalia    Uganda  South Africa  Zimbabwe
# 0     -0.688648 -2.375751 -1.418792     -0.253671 -1.521978
# 1     -1.080389 -2.575844 -1.561003     -0.311745 -1.088343
# 2     -0.513328 -2.880443 -1.305026     -0.131361 -1.207500
# 3     -0.479250 -2.709518 -1.417637     -0.162605 -1.272914
# 4     -0.302184 -2.748559 -1.140198      0.048197 -0.932961

# %%
#renaming the column that has the years
Stability_df1 = Stability_df.rename(columns={"Unnamed: 0": "Year"})
Stability_df1.head()
# Out:
#    Year    Angola   Burundi     Benin  Ethiopia     Ghana     Kenya  \
# 0  2002 -1.577046 -2.288240  0.820294 -1.223214 -0.163768 -1.186471
# 1  2003 -1.006538 -2.244527  0.679064 -1.408554  0.028774 -1.262862
# 2  2004 -1.062798 -2.523785  0.265107 -1.311482  0.039967 -1.086909
# 3  2005 -0.887544 -1.524742  0.446816 -1.690749  0.168321 -1.249828
# 4  2006 -0.541986 -1.427005  0.547010 -1.738937  0.008032 -1.125182
#
#    Madagascar      Mali  Mozambique   Namibia   Nigeria    Rwanda   Senegal  \
# 0   -0.230007  0.410803    0.186406  0.145299 -1.625118 -1.653260 -0.274071
# 1    0.621700  0.258126    0.246201  0.477721 -1.633998 -1.112363 -0.249980
# 2    0.244328  0.453275    0.002372  0.664466 -1.753987 -1.187092  0.028721
# 3   -0.021505  0.175682    0.124558  0.625277 -1.667195 -1.002252 -0.204454
# 4    0.183486  0.413544    0.519501  0.782987 -2.034141 -0.682115 -0.264090
#
#    Sierra Leone   Somalia    Uganda  South Africa  Zimbabwe
# 0     -0.688648 -2.375751 -1.418792     -0.253671 -1.521978
# 1     -1.080389 -2.575844 -1.561003     -0.311745 -1.088343
# 2     -0.513328 -2.880443 -1.305026     -0.131361 -1.207500
# 3     -0.479250 -2.709518 -1.417637     -0.162605 -1.272914
# 4     -0.302184 -2.748559 -1.140198      0.048197 -0.932961

# %%
#show the table
Stability_df1.set_index('Year', drop=True)
# Out:
#         Angola   Burundi     Benin  Ethiopia     Ghana     Kenya  Madagascar  \
# Year
# 2002 -1.577046 -2.288240  0.820294 -1.223214 -0.163768 -1.186471   -0.230007
# 2003 -1.006538 -2.244527  0.679064 -1.408554  0.028774 -1.262862    0.621700
# 2004 -1.062798 -2.523785  0.265107 -1.311482  0.039967 -1.086909    0.244328
# 2005 -0.887544 -1.524742  0.446816 -1.690749  0.168321 -1.249828   -0.021505
# 2006 -0.541986 -1.427005  0.547010 -1.738937  0.008032 -1.125182    0.183486
# 2007 -0.666032 -1.375335  0.386123 -1.803412 -0.071786 -1.302541    0.089658
# 2008 -0.362911 -1.638164  0.374591 -1.730085 -0.027629 -1.391941   -0.470053
# 2009 -0.347262 -1.272694  0.403298 -1.640794  0.029943 -1.425457   -0.732853
# 2010 -0.226182 -1.625959  0.261260 -1.635101  0.026093 -1.165524   -0.978339
# 2011 -0.369238 -1.807200  0.318356 -1.506964  0.167112 -1.244791   -0.705586
# 2012 -0.389323 -1.704738  0.364368 -1.564271  0.130695 -1.323441   -0.536137
# 2013 -0.391234 -1.350278  0.301189 -1.407307  0.060606 -1.166931   -0.659993
# 2014 -0.333232 -0.784407  0.027140 -1.339387 -0.106808 -1.282247   -0.557236
# 2015 -0.500898 -1.939511 -0.013514 -1.498187 -0.032099 -1.244406   -0.427363
# 2016 -0.315899 -1.970721 -0.002027 -1.619813 -0.130929 -1.354791   -0.290095
# 2017 -0.294626 -1.970385  0.045325 -1.687409  0.086481 -1.084383   -0.334092
#
#           Mali  Mozambique   Namibia   Nigeria    Rwanda   Senegal  \
# Year
# 2002  0.410803    0.186406  0.145299 -1.625118 -1.653260 -0.274071
# 2003  0.258126    0.246201  0.477721 -1.633998 -1.112363 -0.249980
# 2004  0.453275    0.002372  0.664466 -1.753987 -1.187092  0.028721
# 2005  0.175682    0.124558  0.625277 -1.667195 -1.002252 -0.204454
# 2006  0.413544    0.519501  0.782987 -2.034141 -0.682115 -0.264090
# 2007  0.230948    0.357609  1.018452 -2.011331 -0.358308 -0.243886
# 2008  0.210366    0.381511  1.200234 -1.860629 -0.323934 -0.147697
# 2009 -0.075571    0.626186  0.928174 -1.995072 -0.506201 -0.204305
# 2010 -0.182899    0.394422  0.846940 -2.211123 -0.272094 -0.417925
# 2011 -0.708380    0.332048  0.911658 -1.956455 -0.177118 -0.280602
# 2012 -2.034329    0.390494  0.978104 -2.042074 -0.230615 -0.108322
# 2013 -1.722162   -0.226966  0.958810 -2.088478 -0.110952 -0.060723
# 2014 -1.713989   -0.336003  0.608741 -2.130276 -0.313470 -0.198223
# 2015 -1.685664   -0.513895  0.733113 -1.925443  0.013241 -0.116665
# 2016 -1.617233   -1.094005  0.710090 -1.877710 -0.054899 -0.218255
# 2017 -1.910102   -0.975530  0.650074 -1.943169  0.039197 -0.044704
#
#       Sierra Leone   Somalia    Uganda  South Africa  Zimbabwe
# Year
# 2002     -0.688648 -2.375751 -1.418792     -0.253671 -1.521978
# 2003     -1.080389 -2.575844 -1.561003     -0.311745 -1.088343
# 2004     -0.513328 -2.880443 -1.305026     -0.131361 -1.207500
# 2005     -0.479250 -2.709518 -1.417637     -0.162605 -1.272914
# 2006     -0.302184 -2.748559 -1.140198      0.048197 -0.932961
# 2007     -0.060830 -3.224753 -0.915109      0.215835 -1.108968
# 2008     -0.238069 -3.280530 -0.876257      0.049733 -1.213945
# 2009     -0.288517 -3.314937 -0.992435     -0.113299 -1.167150
# 2010     -0.236645 -3.130971 -1.000558     -0.029427 -1.104014
# 2011     -0.168445 -3.083847 -0.976102      0.024032 -0.945329
# 2012     -0.279945 -2.860755 -0.868967     -0.025387 -0.778662
# 2013     -0.174718 -2.758687 -0.838691     -0.046295 -0.665950
# 2014     -0.104040 -2.515828 -0.941126     -0.146389 -0.713570
# 2015     -0.102517 -2.380828 -0.804502     -0.212993 -0.618156
# 2016     -0.159926 -2.357363 -0.715323     -0.141504 -0.619938
# 2017      0.029830 -2.326141 -0.557396     -0.267319 -0.774265

# %%
#pivot columns into rows
Stability_pivot = Stability_df1.melt(id_vars=["Year"], 
        var_name="Country", 
        value_name="Total Stability")
Stability_pivot.head(10)
# Out:
#    Year Country  Total Stability
# 0  2002  Angola        -1.577046
# 1  2003  Angola        -1.006538
# 2  2004  Angola        -1.062798
# 3  2005  Angola        -0.887544
# 4  2006  Angola        -0.541986
# 5  2007  Angola        -0.666032
# 6  2008  Angola        -0.362911
# 7  2009  Angola        -0.347262
# 8  2010  Angola        -0.226182
# 9  2011  Angola        -0.369238

# %%
#merge Aid and Stability tables using the variable Country and Year
Combined_data = pd.merge(Aid_df, Stability_pivot, on=['Country','Year'])

# %%
# Rename Grand Total for Total Aid
Combined_Aid_Stability = Combined_data.rename(index=str, columns={"Grand Total": "Total Aid"})

Combined_Aid_Stability.head(10)
# Out:
#   Country  Year      Economic       Military     Total Aid  Total Stability
# 0  Angola  2002  1.659227e+08       0.000000  1.659227e+08        -1.577046
# 1  Angola  2003  2.155944e+08  395057.529807  2.159894e+08        -1.006538
# 2  Angola  2004  1.520490e+08  638258.217553  1.526873e+08        -1.062798
# 3  Angola  2005  8.311513e+07  387385.061877  8.350252e+07        -0.887544
# 4  Angola  2006  9.623060e+07  768343.338990  9.699894e+07        -0.541986
# 5  Angola  2007  6.191552e+07  512302.664188  6.242783e+07        -0.666032
# 6  Angola  2008  6.537215e+07  396706.828528  6.576886e+07        -0.362911
# 7  Angola  2009  6.095525e+07  535667.400000  6.149092e+07        -0.347262
# 8  Angola  2010  1.114652e+08  417850.218081  1.118831e+08        -0.226182
# 9  Angola  2011  8.945588e+07  458935.004372  8.991482e+07        -0.369238

# %%
#print the combined table into a csv file
Combined_Aid_Stability.to_csv(r'outcomes/Aid_Stability_data.csv')

# %%
#Renaming the file as it will include 2 year lag in Economic and Military Aid
Combined_Aid_Stability_2 = Combined_Aid_Stability.rename(index=str, columns={"Economic": "Economic_2", "Military": "Military_2"})
Combined_Aid_Stability_4 = Combined_Aid_Stability.rename(index=str, columns={"Economic": "Economic_4", "Military": "Military_4"})
Combined_Aid_Stability_6 = Combined_Aid_Stability.rename(index=str, columns={"Economic": "Economic_6", "Military": "Military_6"})


#adding two years to see effect
Combined_Aid_Stability_2['Economic_2'] = Combined_Aid_Stability_2['Economic_2'].shift(-2)
Combined_Aid_Stability_2['Military_2'] = Combined_Aid_Stability_2['Military_2'].shift(-2)
Combined_Aid_Stability_2= Combined_Aid_Stability_2.dropna()

#adding four years to see effect
Combined_Aid_Stability_4['Economic_4'] = Combined_Aid_Stability_4['Economic_4'].shift(-4)
Combined_Aid_Stability_4['Military_4'] = Combined_Aid_Stability_4['Military_4'].shift(-4)
Combined_Aid_Stability_4= Combined_Aid_Stability_4.dropna()

#adding six years to see effect
Combined_Aid_Stability_6['Economic_6'] = Combined_Aid_Stability_6['Economic_6'].shift(-6)
Combined_Aid_Stability_6['Military_6'] = Combined_Aid_Stability_6['Military_6'].shift(-6)
Combined_Aid_Stability_6= Combined_Aid_Stability_6.dropna()

# %%
#Scatter Economic vs Stability for Year on Year 
plt.scatter(Combined_Aid_Stability['Economic'], Combined_Aid_Stability['Total Stability'], color='red')
plt.title('Economic Aid vs Stability Rate - Year to Year', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Economic vs Stability for funding 2 years after 
plt.scatter(Combined_Aid_Stability_2['Economic_2'], Combined_Aid_Stability_2['Total Stability'], color='red')
plt.title('Economic Aid vs Stability Rate - Funding 2 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Economic vs Stability for funding 4 years after 
plt.scatter(Combined_Aid_Stability_4['Economic_4'], Combined_Aid_Stability_4['Total Stability'], color='red')
plt.title('Economic Aid vs Stability Rate - Funding 4 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Economic vs Stability for funding 6 years after 
plt.scatter(Combined_Aid_Stability_6['Economic_6'], Combined_Aid_Stability_6['Total Stability'], color='red')
plt.title('Economic Aid vs Stability Rate - Funding 6 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Military vs Stability for funding on Year
plt.scatter(Combined_Aid_Stability['Military'], Combined_Aid_Stability['Total Stability'], color='green')
plt.title('Military Aid vs Stability Rate - Year to Year', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Military vs Stability for funding 2 years after
plt.scatter(Combined_Aid_Stability_2['Military_2'], Combined_Aid_Stability_2['Total Stability'], color='green')
plt.title('Military Aid vs Stability Rate - Funding 2 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Military vs Stability for funding 4 years after
plt.scatter(Combined_Aid_Stability_4['Military_4'], Combined_Aid_Stability_4['Total Stability'], color='green')
plt.title('Military Aid vs Stability Rate - Funding 4 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Military vs Stability for funding 6 years after
plt.scatter(Combined_Aid_Stability_6['Military_6'], Combined_Aid_Stability_6['Total Stability'], color='green')
plt.title('Military Aid vs Stability Rate - Funding 6 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()

# %%
#Renaming the file as it will include 2 year lag in Stability Rate
Combined_Aid_Stability_S2 = Combined_Aid_Stability.rename(index=str, columns={"Total Stability": "Total Stability_2"})
Combined_Aid_Stability_S4 = Combined_Aid_Stability.rename(index=str, columns={"Total Stability": "Total Stability_4"})
Combined_Aid_Stability_S6 = Combined_Aid_Stability.rename(index=str, columns={"Total Stability": "Total Stability_6"})


#adding two years to see effect
Combined_Aid_Stability_S2['Total Stability_2'] = Combined_Aid_Stability_S2['Total Stability_2'].shift(-2)
Combined_Aid_Stability_S2= Combined_Aid_Stability_S2.dropna()

#adding four years to see effect
Combined_Aid_Stability_S4['Total Stability_4'] = Combined_Aid_Stability_S4['Total Stability_4'].shift(-4)
Combined_Aid_Stability_S4= Combined_Aid_Stability_S4.dropna()

#adding six years to see effect
Combined_Aid_Stability_S6['Total Stability_6'] = Combined_Aid_Stability_S6['Total Stability_6'].shift(-6)
Combined_Aid_Stability_S6= Combined_Aid_Stability_S6.dropna()

# %%
#Scatter Economic vs Stability for Year on Year 
plt.scatter(Combined_Aid_Stability['Economic'], Combined_Aid_Stability['Total Stability'], color='black')
plt.title('Economic Aid vs Stability - Year to Year', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Economic vs Stability for Stability after 2 Years 
plt.scatter(Combined_Aid_Stability_S2['Economic'], Combined_Aid_Stability_S2['Total Stability_2'], color='black')
plt.title('Economic Aid vs Stability - Stability 2 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Economic vs Stability for Stability 4 years after 
plt.scatter(Combined_Aid_Stability_S4['Economic'], Combined_Aid_Stability_S4['Total Stability_4'], color='black')
plt.title('Economic Aid vs Stability - Stability 4 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Economic vs Stability for Stability 6 years after 
plt.scatter(Combined_Aid_Stability_S6['Economic'], Combined_Aid_Stability_S6['Total Stability_6'], color='black')
plt.title('Economic Aid vs Stability - Stability 6 Years After', fontsize=14)
plt.xlabel('Economic Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Military vs Stability for funding on Year
plt.scatter(Combined_Aid_Stability['Military'], Combined_Aid_Stability['Total Stability'], color='orange')
plt.title('Military Aid vs Stability - Year to Year', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Military vs Stability for funding 2 years after
plt.scatter(Combined_Aid_Stability_S2['Military'], Combined_Aid_Stability_S2['Total Stability_2'], color='orange')
plt.title('Military Aid vs Stability - Stability 2 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Military vs Stability for funding 4 years after
plt.scatter(Combined_Aid_Stability_S4['Military'], Combined_Aid_Stability_S4['Total Stability_4'], color='orange')
plt.title('Military Aid vs Stability - Stability 4 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()
#Scatter Military vs Stability for funding 6 years after
plt.scatter(Combined_Aid_Stability_S6['Military'], Combined_Aid_Stability_S6['Total Stability_6'], color='orange')
plt.title('Military Aid vs Stability - Stability 6 Years After', fontsize=14)
plt.xlabel('Military Aid', fontsize=14)
plt.ylabel('Stability Rate', fontsize=14)
plt.grid(True)
plt.show()

# %%
from sklearn import linear_model

X2 = Combined_Aid_Stability_S2[['Economic','Military']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y2 = Combined_Aid_Stability_S2['Total Stability_2']

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X2, Y2)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -0.423871404569839
# Coefficients:
#  [-8.62903024e-10 -4.77263137e-09]

# %%
#Stability_2 mean
Combined_Aid_Stability_S2["Total Stability_2"].mean()
# Out:
# -0.6908089130909094

# %%
#Stability_2 = (-0.423871404569839) + (-8.62903024e-10)*Economic + (-4.77263137e-09)*Military
# prediction with sklearn
Military_Funding = 1
Economic_Funding = 0.4
print ('Predicted Stability in 2 years: \n', regr.predict([[Military_Funding, Economic_Funding]]))
# Out:
# Predicted Stability in 2 years:
#  [-0.42387141]

# %%
X4 = Combined_Aid_Stability_S4[['Economic','Military']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y4 = Combined_Aid_Stability_S4['Total Stability_4']

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X4, Y4)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -0.3918945767486449
# Coefficients:
#  [-8.41260088e-10 -8.32429159e-09]

# %%
#Stability_4 mean
Combined_Aid_Stability_S4["Total Stability_4"].mean()
# Out:
# -0.688725674725275

# %%
#Stability_4 = (-0.3918945767486449) + (-8.41260088e-10)*Economic + (-8.32429159e-09)*Military
# prediction with sklearn
Military_Funding = 1
Economic_Funding = 0.4
print ('Predicted Stability in 4 years: \n', regr.predict([[Military_Funding, Economic_Funding]]))
# Out:
# Predicted Stability in 4 years:
#  [-0.39189458]

# %%
X6 = Combined_Aid_Stability_S6[['Economic','Military']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y6 = Combined_Aid_Stability_S6['Total Stability_6']

# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X6, Y6)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  -0.40542644384965976
# Coefficients:
#  [-7.28203381e-10 -9.85593150e-09]

# %%
#Stability_6 = (-0.40542644384965976) + (-7.28203381e-10)*Economic + (-9.85593150e-09)*Military
# prediction with sklearn
Military_Funding = 1
Economic_Funding = 0.4
print ('Predicted Stability in 6 years: \n', regr.predict([[Military_Funding, Economic_Funding]]))
# Out:
# Predicted Stability in 6 years:
#  [-0.40542645]

# %%
#Stability_6 mean
Combined_Aid_Stability_S6["Total Stability_6"].mean()
# Out:
# -0.6893508892988933

# %%
# Out:
# <div>
#
#
#             <div id="c0d48a47-891f-4bba-b04c-9eafaa6012e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c0d48a47-891f-4bba-b04c-9eafaa6012e3")) {
#                     Plotly.newPlot(
#                         'c0d48a47-891f-4bba-b04c-9eafaa6012e3',
#                         [{"marker": {"color": ["rgb(255, 153, 51)", "rgb(55, 128, 191)", "rgb(50, 171, 96)", "rgb(128, 0, 128)", "rgb(219, 64, 82)", "rgb(0, 128, 128)", "rgb(255, 255, 51)", "rgb(128, 128, 0)", "rgb(251, 128, 114)", "rgb(128, 177, 211)"], "line": {"width": 1.3}, "size": [24, 29, 23, 17, 18, 15, 15, 15, 19, 18, 17, 15, 15, 15, 16, 16, 13, 13, 13, 12, 12, 42, 13, 14, 14, 14, 14, 12, 14, 20, 13, 46, 12, 15, 15, 16, 15, 13, 13, 16, 15, 16, 15, 15, 13, 14, 16, 16, 27, 80, 51, 83, 42, 52, 102, 95, 91, 76, 85, 77, 77, 82, 109, 106, 18, 18, 19, 18, 19, 70, 17, 19, 20, 23, 24, 23, 26, 36, 73, 26, 23, 22, 28, 34, 46, 53, 56, 86, 66, 96, 104, 94, 91, 94, 112, 102, 14, 15, 14, 27, 15, 16, 17, 15, 15, 17, 16, 14, 15, 24, 19, 20, 14, 14, 17, 16, 17, 63, 15, 20, 22, 23, 37, 29, 25, 28, 33, 30, 27, 21, 23, 21, 25, 32, 85, 38, 39, 29, 42, 37, 40, 40, 55, 60, 12, 14, 14, 15, 16, 18, 20, 47, 18, 17, 20, 16, 15, 14, 14, 14, 22, 20, 21, 26, 29, 42, 52, 48, 50, 46, 61, 58, 64, 63, 74, 84, 16, 15, 16, 19, 19, 21, 21, 24, 27, 27, 26, 24, 26, 32, 34, 25, 14, 16, 16, 15, 16, 16, 18, 20, 74, 23, 24, 21, 21, 20, 19, 27, 16, 15, 12, 12, 12, 12, 12, 12, 13, 13, 12, 12, 13, 29, 19, 15, 14, 13, 13, 15, 21, 24, 40, 54, 25, 36, 54, 52, 46, 32, 34, 61, 24, 19, 27, 28, 31, 48, 45, 68, 55, 56, 59, 58, 57, 42, 63, 54, 21, 33, 32, 41, 38, 40, 50, 48, 51, 38, 53, 63, 61, 63, 76, 74, 16, 13, 13, 16, 13, 24, 29, 38, 31, 25, 25, 26, 25, 27, 33, 27], "symbol": "circle"}, "mode": "markers", "text": ["Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Somalia", "Somalia", "S ...

# %%
#get rid of Military, Economic Aid and year to see which 5 countries received more funding in the sample
Summary_Aid_Stability = Combined_Aid_Stability.drop(columns=['Economic', 'Military', 'Year', 'Total Stability'])
Summary_Aid_Stability.head(10)
# Out:
#   Country     Total Aid
# 0  Angola  1.659227e+08
# 1  Angola  2.159894e+08
# 2  Angola  1.526873e+08
# 3  Angola  8.350252e+07
# 4  Angola  9.699894e+07
# 5  Angola  6.242783e+07
# 6  Angola  6.576886e+07
# 7  Angola  6.149092e+07
# 8  Angola  1.118831e+08
# 9  Angola  8.991482e+07

# %%
Summary_Aid_Stability_df = Summary_Aid_Stability.groupby('Country')[['Total Aid']].sum()
Summary_Aid_Stability_df.head(10)
# Out:
#                Total Aid
# Country
# Angola      1.506143e+09
# Benin       1.426953e+09
# Burundi     9.177332e+08
# Ethiopia    1.237565e+10
# Ghana       3.375036e+09
# Kenya       1.087626e+10
# Madagascar  1.341919e+09
# Mali        2.819429e+09
# Mozambique  5.254134e+09
# Namibia     1.490758e+09

# %%
Summary_Aid_Stability_df.sort_values(by=['Total Aid'], ascending=False)
# Out:
#                  Total Aid
# Country
# Ethiopia      1.237565e+10
# Kenya         1.087626e+10
# Uganda        7.154487e+09
# Nigeria       6.914687e+09
# South Africa  6.637084e+09
# Mozambique    5.254134e+09
# Somalia       4.318955e+09
# Ghana         3.375036e+09
# Mali          2.819429e+09
# Rwanda        2.471997e+09
# Senegal       2.347146e+09
# Angola        1.506143e+09
# Namibia       1.490758e+09
# Benin         1.426953e+09
# Madagascar    1.341919e+09
# Burundi       9.177332e+08
# Sierra Leone  8.285264e+08
# Zimbabwe      2.700432e+08

# %%
select_country_df = Combined_Aid_Stability.loc[(Combined_Aid_Stability['Country']=="Ethiopia")|
(Combined_Aid_Stability['Country']=="Kenya")|(Combined_Aid_Stability['Country']=="Uganda")|
(Combined_Aid_Stability['Country']=="Nigeria")|
(Combined_Aid_Stability['Country']=="South Africa"),:]
select_country_df.head(10)
# Out:
#      Country  Year      Economic      Military     Total Aid  Total Stability
# 48  Ethiopia  2002  7.709543e+08  1.420680e+06  2.003328e+08        -1.223214
# 49  Ethiopia  2003  7.662703e+08  5.809056e+06  8.012913e+08        -1.408554
# 50  Ethiopia  2004  8.074779e+08  2.487397e+07  4.695278e+08        -1.311482
# 51  Ethiopia  2005  1.121195e+09  9.240170e+06  8.408363e+08        -1.690749
# 52  Ethiopia  2006  1.102311e+09  6.478230e+05  3.687738e+08        -1.738937
# 53  Ethiopia  2007  9.235276e+07  2.042365e+06  4.870683e+08        -1.803412
# 54  Ethiopia  2008  9.362114e+07  2.066203e+06  1.060347e+09        -1.730085
# 55  Ethiopia  2009  1.078195e+08  2.116464e+06  9.770186e+08        -1.640794
# 56  Ethiopia  2010  9.069992e+07  1.634938e+06  9.321989e+08        -1.635101
# 57  Ethiopia  2011  1.084510e+08  1.546276e+06  7.633135e+08        -1.506964

# %%
#Creating a Scatter bubble graph comparing Aid vs Stability by year using the following variables:
#x_axis = Year
#y = stability
#x1 = Total Aid # size of the bubble

#pip install cufflinks in GitBash

select_country_df.iplot(kind='bubble', x='Year', mode='markers', y='Total Stability', size='Total Aid', text='Country',
             xTitle='Year', yTitle='Stability Index',
             filename='Aid_vs_Stability_bubbleplot')
# Out:
# <div>
#
#
#             <div id="60ee73f8-0539-47ea-b70f-87640a3822cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("60ee73f8-0539-47ea-b70f-87640a3822cf")) {
#                     Plotly.newPlot(
#                         '60ee73f8-0539-47ea-b70f-87640a3822cf',
#                         [{"marker": {"color": ["rgb(255, 153, 51)", "rgb(55, 128, 191)", "rgb(50, 171, 96)", "rgb(128, 0, 128)", "rgb(219, 64, 82)", "rgb(0, 128, 128)", "rgb(255, 255, 51)", "rgb(128, 128, 0)", "rgb(251, 128, 114)", "rgb(128, 177, 211)"], "line": {"width": 1.3}, "size": [21, 77, 46, 81, 36, 48, 102, 94, 90, 74, 83, 75, 75, 80, 108, 106, 16, 15, 22, 28, 41, 48, 52, 84, 62, 95, 103, 93, 89, 93, 112, 102, 15, 13, 14, 19, 23, 36, 47, 43, 45, 41, 57, 54, 60, 59, 71, 82, 17, 12, 20, 22, 25, 43, 40, 65, 51, 52, 55, 54, 53, 36, 59, 50, 14, 27, 26, 36, 33, 34, 45, 43, 46, 32, 48, 59, 57, 59, 73, 72], "symbol": "circle"}, "mode": "markers", "text": ["Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda"], "type": "scatter", "uid": "7919837f-1d45-464e-8aa0-42500acdef7b", "x": [2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], "y": [-1.223214, -1.408554, -1.311482, -1.690749, -1.738937, -1.8034119999999998, -1.7300849999999999, -1.6407939999999999, -1.635101, -1.506964, -1.564271, -1.4073069999999999, -1.339387, -1.4981870000000002, -1.619813, -1.687409, -1.1864709999999998, -1.2628620000000002, -1.0869090000000001, -1.2498280000000002, -1.125182, -1.302541, -1.391941, -1.425457, -1.165524, -1.244791, -1.323441, -1.166931, -1.282247, -1.244406, -1.354791, -1.084383, -1.625118, -1.633998, -1.753987, -1.667195, -2.034141, -2.011331, -1.860629, -1.9950720000000002, -2.211123, -1.9564549999999998, -2.042074, -2.088478, -2.130276, -1.925443, -1.8777099999999998, -1.943169, -0.25367080000000003, -0.3117453, -0.1313613, -0.1626052, 0.0481969, 0.2158346, 0.0497333, -0.1132994, -0.029427, 0.024031599999999997, -0.0253867, -0.0462945, -0.14638900000000002, -0.2129929, -0.141504, -0.2673192, -1.418792, -1.5610030000000001, -1.305026, -1.417637, -1.140198, -0.9151093000000001, -0.8762574000000001, -0.9924353000000001, -1.000558, -0.9761018, -0.8689665000000001, -0.8386906, -0.9411261999999999, -0.8045017, -0.7153227, -0.5573964]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Stability Index"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('60ee73f8-0539-47ea-b70f-87640a3822cf');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
import scipy.stats as stats
# Create a boxplot to compare means between selected countries
select_country_df.boxplot("Total Aid", by="Country", figsize=(20, 10))

# %%
# Create a boxplot to compare means between selected countries
select_country_df.boxplot("Total Stability", by="Country", figsize=(20, 10))

# %%
# Extract individual groups
group1 = select_country_df[select_country_df["Country"] == "Ethiopia"]["Total Aid"]
group2 = select_country_df[select_country_df["Country"] == "Kenya"]["Total Aid"]
group3 = select_country_df[select_country_df["Country"] == "Nigeria"]["Total Aid"]
group4 = select_country_df[select_country_df["Country"] == "South Africa"]["Total Aid"]
group5 = select_country_df[select_country_df["Country"] == "Uganda"]["Total Aid"]

# %%
# Perform the ANOVA
stats.f_oneway(group1, group2, group3, group4, group5)
# Out:
# F_onewayResult(statistic=6.906118385388987, pvalue=8.669324232697205e-05)

# %%
# multiple line plot
plt.plot( 'x', 'y1', data=select_country_df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=select_country_df, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=select_country_df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend()
# Out:
# <div>
#
#
#             <div id="73747d2a-21cf-4438-ac61-b078cbf00841" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("73747d2a-21cf-4438-ac61-b078cbf00841")) {
#                     Plotly.newPlot(
#                         '73747d2a-21cf-4438-ac61-b078cbf00841',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "Total Aid", "text": ["Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda"], "type": "scatter", "uid": "9be01b2f-a216-4363-82f8-8590d28deb4a", "x": [2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], "y": [200332785.7580824, 801291287.599558, 469527773.3878823, 840836346.1287591, 368773783.69630486, 487068332.4570397, 1060346974.7980808, 977018632.1383413, 932198906.7878768, 763313455.710154, 864741985.6086813, 772374940.3565159, 772079325.1579442, 832351844.040516, 1130434925.6029224, 1102958376.526244, 150540358.1987579, 137003112.80936453, 210433589.58314818, 281399369.6686464, 412057962.0630669, 490730964.8423536, 529611449.67294395, 870294214.9664885, 642279795.9983029, 989758383.5867848, 1078945071.2721379, 964719626.792772, 928231199.904496, 965992435.3796774, 1163860956.1578484, 1060401019.2764363, 136553962.69307664, 115639864.78716627, 132347114.93141313, 189015427.6289136, 226188076.2441345, 368896918.3202757, 479414074.8842043, 437105795.0967932, 457601850.6117021, 416248842.9515533, 590831978.2794539, 551683741.9000908, 620192081.332146, 610075692.5585877, 731012692.4514933, 851878623.163139, 159530635.6498019, 104341139.99281168, 193805698.3327551, 213830843.7909462, 245187580.60084677, 440535517.8828814, 408687083.0500607, 668144816.4513723, 523344926.81842685, 533535505.7217924, 564899990.5899166, 556465221.1266288, 540438559.5267628, 365391897.38889647, 607460080.8978968, 511484217.8307998, 125760105.19325, 263955183.709904, 258691586.34139514, 363683493.8349863, 327859691.60526645, 341897266.59925437, 459614268.2925372, 436038983.3702868, 474806668.3743645, 323069886.97178364, 492183560.5610796, 604004214.1517254, 581540397.3421197, 605118676.2267714, 755494385.6064986, 740768874.9499998]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Year"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Aid Amount"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('73747d2a-21cf-4438-ac61-b078cbf00841');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
#using iplot create a bunch of graphs 
Summary_Aid_Stability.scatter_matrix(filename='Aid_vs_Stability_scatter-matrix', world_readable=True)
# Out:
# <div>
#
#
#             <div id="9646247a-6de6-427f-8da8-93423bfec6a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9646247a-6de6-427f-8da8-93423bfec6a2")) {
#                     Plotly.newPlot(
#                         '9646247a-6de6-427f-8da8-93423bfec6a2',
#                         [{"histfunc": "count", "histnorm": "", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#4D5663", "width": 1.3}}, "name": "Country", "nbinsx": 10, "opacity": 0.8, "orientation": "v", "type": "histogram", "uid": "d7610f6c-8bed-4c69-9dd9-d796216bec83", "x": ["Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Angola", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Benin", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Burundi", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ethiopia", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Ghana", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Kenya", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Madagascar", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mali", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Mozambique", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Namibia", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Nigeria", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Rwanda", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Senegal", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Sierra Leone", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "Somalia", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "South Africa", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Uganda", "Zimbabwe", "Zimbabwe", "Zimbabwe", "Zimbabwe", "Zimbabwe"], "xaxis": "x", "yaxis": "y"}, {"line": {"color": "rgba(128, 128, 128, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 2, "symbol": "circle"}, "mode": "markers", "name": "Country", "text": "", "type": "scatter", "uid": "679bc812-7487-42b7-a82a-cd1a4a484129", "x": [165922662.62838554, 215989414.30960298, 152687271.9015792, 83502515.1007885, 96998944.34773123, 62427827.609634444, 65768859.16086496, 61490919.143439025, 111883100.03812057, 89914817.86025062, 79970967.38030244, 58307991.28226402, 57364444.72605325, 60014510.89769734, 6830396 ...
