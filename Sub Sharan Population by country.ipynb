# %%
import wbpy
import pandas as pd

# %%
api = wbpy.IndicatorAPI()

# %%
import wbpy
from pprint import pprint

api = wbpy.IndicatorAPI()

iso_country_codes = ["KEN", "ZAF", "NGA", "ZWE", "ETH", "UGA",
                   "GHA", "SEN", "MDG", "MOZ", "NAM", "BDI",
                  "BEN", "SOM", "MLI", "AGO", "SLE", "RWA"]
total_population = "SP.POP.TOTL"

dataset_popl = api.get_dataset(total_population, iso_country_codes, date="2001:2017")
dataset
# Out:
# <wbpy.indicators.IndicatorDataset('SP.POP.TOTL', 'Population, total') with id: 2874525117912>

# %%
d6=dataset_popl.as_dict()

# %%
Populationtotal6_df=pd.DataFrame(data=d6)

# %%
Populationtotal6_df
# Out:
#               AO          BI          BJ           ET          GH          KE  \
# 2001  16945753.0   6525545.0   7076733.0   68159423.0  19756928.0  32848564.0
# 2002  17519417.0   6704113.0   7295394.0   70142091.0  20246381.0  33751739.0
# 2003  18121479.0   6909154.0   7520555.0   72170584.0  20750299.0  34678779.0
# 2004  18758145.0   7131693.0   7750004.0   74239505.0  21272323.0  35635271.0
# 2005  19433602.0   7364862.0   7982225.0   76346311.0  21814642.0  36624895.0
# 2006  20149901.0   7607849.0   8216897.0   78489206.0  22379055.0  37649033.0
# 2007  20905363.0   7862214.0   8454793.0   80674348.0  22963946.0  38705932.0
# 2008  21695634.0   8126102.0   8696921.0   82916235.0  23563825.0  39791981.0
# 2009  22514281.0   8397668.0   8944708.0   85233913.0  24170940.0  40901792.0
# 2010  23356246.0   8675602.0   9199259.0   87639964.0  24779619.0  42030676.0
# 2011  24220661.0   8958406.0   9460830.0   90139927.0  25387710.0  43178257.0
# ...

# %%
Populationtotal7_df = Populationtotal6_df.rename(columns={"AO":"Angola", "BI": "Burundi", "BJ": "Benin", "ET":"Ethiopia", "GH": "Ghana", "KE":"Kenya", "MG": "Madagascar", "ML":"Malawi", "MZ":"Mozambique",  "NA": "Namibia", "NG":"Nigeria", "RW":"Rwanda", "SN": "Senegal", "SL":"Sierra Leone", "SO": "Somalia", "UG":"Uganda", "ZA":"South Africa", "ZW":"Zimbabwe"})
