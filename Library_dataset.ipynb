# %%
#Dependencies

import pandas as pd
import numpy as np
import wbpy
from pprint import pprint

# %%
api = wbpy.IndicatorAPI()

iso_country_codes = ["KEN", "ZA", "NGA", "ZWE", "ETH", "UGA",
                     "GHA", "SEN", "MDG", "MOZ", "NAM"]
stability = "PV.EST"

dataset_EST = api.get_dataset(stability, iso_country_codes, date="2010:2017")
dataset_EST
# Out:
# <wbpy.indicators.IndicatorDataset('PV.EST', 'Political Stability and Absence of Violence/Terrorism: Estimate') with id: 2590146022760>

# %%
d=dataset_EST.as_dict()

# %%
stabilityscore_df=pd.DataFrame(data=d)

# %%
stabilityscore_df
# Out:
#             ET        GH        KE        MG        MZ        NA        NG  \
# 2010 -1.635101  0.026093 -1.165524 -0.978339  0.394422  0.846940 -2.211123
# 2011 -1.506964  0.167112 -1.244791 -0.705586  0.332048  0.911658 -1.956455
# 2012 -1.564271  0.130695 -1.323441 -0.536137  0.390494  0.978104 -2.042074
# 2013 -1.407307  0.060606 -1.166931 -0.659993 -0.226966  0.958810 -2.088478
# 2014 -1.339387 -0.106808 -1.282247 -0.557236 -0.336003  0.608741 -2.130276
# 2015 -1.498187 -0.032099 -1.244406 -0.427363 -0.513895  0.733113 -1.925443
# 2016 -1.619813 -0.130929 -1.354791 -0.290095 -1.094005  0.710090 -1.877710
# 2017 -1.687409  0.086481 -1.084383 -0.334092 -0.975530  0.650074 -1.943169
#
#             SN        UG        ZA        ZW
# 2010 -0.417925 -1.000558 -0.029427 -1.104014
# 2011 -0.280602 -0.976102  0.024032 -0.945329
# 2012 -0.108322 -0.868966 -0.025387 -0.778662
# 2013 -0.060723 -0.838691 -0.046295 -0.665950
# 2014 -0.198223 -0.941126 -0.146389 -0.713570
# ...
