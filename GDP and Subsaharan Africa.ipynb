# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
GDP_data_to_load="GDP_by_$.xlsx"

# %%
GDP_df = pd.read_excel(GDP_data_to_load)

# %%
file1 = "Economic_vs_Military.xlsx"
Aid_df = pd.read_excel(file1)
Aid_df
# Out:
#     Row Labels  Year      Economic      Military   Grand Total
# 0       Angola  2002  1.659227e+08  0.000000e+00  1.659227e+08
# 1       Angola  2003  2.155944e+08  3.950575e+05  2.159894e+08
# 2       Angola  2004  1.520490e+08  6.382582e+05  1.526873e+08
# 3       Angola  2005  8.311513e+07  3.873851e+05  8.350252e+07
# 4       Angola  2006  9.623060e+07  7.683433e+05  9.699894e+07
# 5       Angola  2007  6.191552e+07  5.123027e+05  6.242783e+07
# 6       Angola  2008  6.537215e+07  3.967068e+05  6.576886e+07
# 7       Angola  2009  6.095525e+07  5.356674e+05  6.149092e+07
# 8       Angola  2010  1.114652e+08  4.178502e+05  1.118831e+08
# 9       Angola  2011  8.945588e+07  4.589350e+05  8.991482e+07
# 10      Angola  2012  7.950237e+07  4.686017e+05  7.997097e+07
# 11      Angola  2013  5.779055e+07  5.174412e+05  5.830799e+07
# 12      Angola  2014  5.685053e+07  5.139185e+05  5.736444e+07
# 13      Angola  2015  5.927624e+07  7.382744e+05  6.001451e+07
# ...

# %%
GDP_df
# Out:
#     Country Name  Year         Total
# 0         Angola  2002  1.528559e+10
# 1         Angola  2003  1.781271e+10
# 2         Angola  2004  2.355205e+10
# 3         Angola  2005  3.697092e+10
# 4         Angola  2006  5.238101e+10
# 5         Angola  2007  6.526645e+10
# 6         Angola  2008  8.853861e+10
# 7         Angola  2009  7.030716e+10
# 8         Angola  2010  8.379950e+10
# 9         Angola  2011  1.117897e+11
# 10        Angola  2012  1.280529e+11
# 11        Angola  2013  1.367099e+11
# 12        Angola  2014  1.457122e+11
# 13        Angola  2015  1.161936e+11
# 14        Angola  2016  1.011239e+11
# 15        Angola  2017  1.221238e+11
# 16         Benin  2002  3.054571e+09
# 17         Benin  2003  3.905366e+09
# 18         Benin  2004  4.521425e+09
# 19         Benin  2005  4.803703e+09
# 20         Benin  2006  5.142381e+09
# 21         Benin  2007  5.969535e+09
# 22         Benin  2008  7.132787e+09
# 23         Benin  2009  7.097199e+09
# ...

# %%
GDP_renamed_df = GDP_df.rename(columns={"Total":"GDP","Country Name":"Country","Year":"Year"})
GDP_renamed_df
# Out:
#       Country  Year           GDP
# 0      Angola  2002  1.528559e+10
# 1      Angola  2003  1.781271e+10
# 2      Angola  2004  2.355205e+10
# 3      Angola  2005  3.697092e+10
# 4      Angola  2006  5.238101e+10
# 5      Angola  2007  6.526645e+10
# 6      Angola  2008  8.853861e+10
# 7      Angola  2009  7.030716e+10
# 8      Angola  2010  8.379950e+10
# 9      Angola  2011  1.117897e+11
# 10     Angola  2012  1.280529e+11
# 11     Angola  2013  1.367099e+11
# 12     Angola  2014  1.457122e+11
# 13     Angola  2015  1.161936e+11
# 14     Angola  2016  1.011239e+11
# 15     Angola  2017  1.221238e+11
# 16      Benin  2002  3.054571e+09
# 17      Benin  2003  3.905366e+09
# 18      Benin  2004  4.521425e+09
# 19      Benin  2005  4.803703e+09
# 20      Benin  2006  5.142381e+09
# 21      Benin  2007  5.969535e+09
# 22      Benin  2008  7.132787e+09
# 23      Benin  2009  7.097199e+09
# 24      Benin  2010  6.970241e+09
# 25      Benin  2011  7.814081e+09
# ...

# %%
Angola_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Angola", :]

# %%
Angola_Country_plot
# Out:
#    Country  Year           GDP
# 0   Angola  2002  1.528559e+10
# 1   Angola  2003  1.781271e+10
# 2   Angola  2004  2.355205e+10
# 3   Angola  2005  3.697092e+10
# 4   Angola  2006  5.238101e+10
# 5   Angola  2007  6.526645e+10
# 6   Angola  2008  8.853861e+10
# 7   Angola  2009  7.030716e+10
# 8   Angola  2010  8.379950e+10
# 9   Angola  2011  1.117897e+11
# 10  Angola  2012  1.280529e+11
# 11  Angola  2013  1.367099e+11
# 12  Angola  2014  1.457122e+11
# 13  Angola  2015  1.161936e+11
# 14  Angola  2016  1.011239e+11
# 15  Angola  2017  1.221238e+11

# %%
Angola_Country_plot=Angola_Country_plot[["Year","GDP"]]

# %%
Angola_Country_plot
# Out:
#     Year           GDP
# 0   2002  1.528559e+10
# 1   2003  1.781271e+10
# 2   2004  2.355205e+10
# 3   2005  3.697092e+10
# 4   2006  5.238101e+10
# 5   2007  6.526645e+10
# 6   2008  8.853861e+10
# 7   2009  7.030716e+10
# 8   2010  8.379950e+10
# 9   2011  1.117897e+11
# 10  2012  1.280529e+11
# 11  2013  1.367099e+11
# 12  2014  1.457122e+11
# 13  2015  1.161936e+11
# 14  2016  1.011239e+11
# 15  2017  1.221238e+11

# %%
Angola_Country_plot_df= Angola_Country_plot.set_index("Year")
Angola_Country_plot_df
# Out:
#                GDP
# Year
# 2002  1.528559e+10
# 2003  1.781271e+10
# 2004  2.355205e+10
# 2005  3.697092e+10
# 2006  5.238101e+10
# 2007  6.526645e+10
# 2008  8.853861e+10
# 2009  7.030716e+10
# 2010  8.379950e+10
# 2011  1.117897e+11
# 2012  1.280529e+11
# 2013  1.367099e+11
# 2014  1.457122e+11
# 2015  1.161936e+11
# 2016  1.011239e+11
# 2017  1.221238e+11

# %%
Aid_df=Aid_df.rename(columns={"Row Labels":"Country"})
Aid_df.head()
Aid_df=Aid_df[["Country","Year","Grand Total"]]
Aid_df=Aid_df.rename(columns={"Grand Total": "Total Aid"})

Aid_df.head()
# Out:
#   Country  Year     Total Aid
# 0  Angola  2002  1.659227e+08
# 1  Angola  2003  2.159894e+08
# 2  Angola  2004  1.526873e+08
# 3  Angola  2005  8.350252e+07
# 4  Angola  2006  9.699894e+07

# %%
Angola_Aid_df = Aid_df.loc[Aid_df["Country"] == "Angola", :]
Angola_Aid_df=Angola_Aid_df[["Year","Total Aid"]]
Angola_Aid_plot=Angola_Aid_df.set_index("Year")
Angola_Aid_plot.head()
# Out:
#          Total Aid
# Year
# 2002  1.659227e+08
# 2003  2.159894e+08
# 2004  1.526873e+08
# 2005  8.350252e+07
# 2006  9.699894e+07

# %%
Angola_chart =Angola_Country_plot_df.plot(kind='bar')
Angola_chart.set_xlabel("Year")
Angola_chart.set_ylabel("GDP (in Hundred Billions)")
Angola_Aid_chart=Angola_Aid_plot.plot.line()
Angola_Aid_chart.set_xlabel("Year")
Angola_Aid_chart.set_ylabel("Total Aid")
plt.show()

# %%
Benin_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Benin", :]
Burundi_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Burundi", :]
Ethiopia_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Ethiopia", :]
Ghana_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Ghana", :]
Kenya_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Kenya", :]
Madagascar_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Madagascar", :]

Mali_Country_plot= GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Mali", :]
Mozambique_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Mozambique", :]
Namibia_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Namibia", :]
Nigeria_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Nigeria", :]
Rwanda_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Rwanda", :]
Senegal_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Senegal", :]
Sierra_Leone_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Sierra Leone", :]
Somalia_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Somalia", :]
South_Africa_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "South Africa", :]
Uganda_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Uganda", :]
Zimbabwe_Country_plot = GDP_renamed_df.loc[GDP_renamed_df["Country"] == "Zimbabwe", :]

# %%
Benin_Country_plot=Benin_Country_plot[["Year","GDP"]]
Burundi_Country_plot=Burundi_Country_plot[["Year","GDP"]]
Ethiopia_Country_plot=Ethiopia_Country_plot[["Year","GDP"]]
Ghana_Country_plot =Ghana_Country_plot[["Year","GDP"]]
Kenya_Country_plot =Kenya_Country_plot[["Year","GDP"]]
Madagascar_Country_plot =Madagascar_Country_plot[["Year","GDP"]]
Mali_Country_plot=Mali_Country_plot[["Year","GDP"]]
Mozambique_Country_plot=Mozambique_Country_plot[["Year","GDP"]]
Namibia_Country_plot=Namibia_Country_plot[["Year","GDP"]]
Nigeria_Country_plot=Nigeria_Country_plot[["Year","GDP"]]
Rwanda_Country_plot=Rwanda_Country_plot[["Year","GDP"]]
Senegal_Country_plot=Senegal_Country_plot[["Year","GDP"]]
Sierra_Leone_Country_plot=Sierra_Leone_Country_plot[["Year","GDP"]]
Somalia_Country_plot=Somalia_Country_plot[["Year","GDP"]]
South_Africa_Country_plot=South_Africa_Country_plot[["Year","GDP"]]
Uganda_Country_plot=Uganda_Country_plot[["Year","GDP"]]
Zimbabwe_Country_plot=Zimbabwe_Country_plot[["Year","GDP"]]

# %%
Benin_Country_plot_df= Benin_Country_plot.set_index("Year")
Burundi_Country_plot_df= Burundi_Country_plot.set_index("Year")
Ethiopia_Country_plot_df= Ethiopia_Country_plot.set_index("Year")
Ghana_Country_plot_df= Ghana_Country_plot.set_index("Year")
Kenya_Country_plot_df= Kenya_Country_plot.set_index("Year")
Madagascar_Country_plot_df= Madagascar_Country_plot.set_index("Year")
Mali_Country_plot_df= Mali_Country_plot.set_index("Year")
Mozambique_Country_plot_df= Mozambique_Country_plot.set_index("Year")
Namibia_Country_plot_df= Namibia_Country_plot.set_index("Year")
Nigeria_Country_plot_df= Nigeria_Country_plot.set_index("Year")
Rwanda_Country_plot_df= Rwanda_Country_plot.set_index("Year")
Senegal_Country_plot_df= Senegal_Country_plot.set_index("Year")
Sierra_Leone_Country_plot_df= Sierra_Leone_Country_plot.set_index("Year")
Somalia_Country_plot_df= Somalia_Country_plot.set_index("Year")
South_Africa_Country_plot_df= South_Africa_Country_plot.set_index("Year")
Uganda_Country_plot_df= Uganda_Country_plot.set_index("Year")
Zimbabwe_Country_plot_df= Zimbabwe_Country_plot.set_index("Year")

# %%
Benin_Aid_df = Aid_df.loc[Aid_df["Country"] == "Benin", :]
Benin_Aid_df=Benin_Aid_df[["Year","Total Aid"]]
Benin_Aid_plot=Benin_Aid_df.set_index("Year")
Burundi_Aid_df = Aid_df.loc[Aid_df["Country"] == "Burundi", :]
Burundi_Aid_df=Burundi_Aid_df[["Year","Total Aid"]]
Burundi_Aid_plot=Burundi_Aid_df.set_index("Year")
Ethiopia_Aid_df = Aid_df.loc[Aid_df["Country"] == "Ethiopia", :]
Ethiopia_Aid_df=Ethiopia_Aid_df[["Year","Total Aid"]]
Ethiopia_Aid_plot=Ethiopia_Aid_df.set_index("Year")
Ghana_Aid_df = Aid_df.loc[Aid_df["Country"] == "Ghana", :]
Ghana_Aid_df=Ghana_Aid_df[["Year","Total Aid"]]
Ghana_Aid_plot=Ghana_Aid_df.set_index("Year")
Kenya_Aid_df = Aid_df.loc[Aid_df["Country"] == "Kenya", :]
Kenya_Aid_df=Kenya_Aid_df[["Year","Total Aid"]]
Kenya_Aid_plot=Kenya_Aid_df.set_index("Year")
Madagascar_Aid_df = Aid_df.loc[Aid_df["Country"] == "Madagascar", :]
Madagascar_Aid_df=Madagascar_Aid_df[["Year","Total Aid"]]
Madagascar_Aid_plot=Madagascar_Aid_df.set_index("Year")
Mali_Aid_df = Aid_df.loc[Aid_df["Country"] == "Mali", :]
Mali_Aid_df=Mali_Aid_df[["Year","Total Aid"]]
Mali_Aid_plot=Mali_Aid_df.set_index("Year")
Mozambique_Aid_df = Aid_df.loc[Aid_df["Country"] == "Mozambique", :]
Mozambique_Aid_df=Mozambique_Aid_df[["Year","Total Aid"]]
Mozambique_Aid_plot=Mozambique_Aid_df.set_index("Year")
Namibia_Aid_df = Aid_df.loc[Aid_df["Country"] == "Namibia", :]
Namibia_Aid_df=Namibia_Aid_df[["Year","Total Aid"]]
Namibia_Aid_plot=Namibia_Aid_df.set_index("Year")
Nigeria_Aid_df = Aid_df.loc[Aid_df["Country"] == "Nigeria", :]
Nigeria_Aid_df=Nigeria_Aid_df[["Year","Total Aid"]]
Nigeria_Aid_plot=Nigeria_Aid_df.set_index("Year")

# %%
Rwanda_Aid_df = Aid_df.loc[Aid_df["Country"] == "Rwanda", :]
Rwanda_Aid_df=Rwanda_Aid_df[["Year","Total Aid"]]
Rwanda_Aid_plot=Rwanda_Aid_df.set_index("Year")
Senegal_Aid_df = Aid_df.loc[Aid_df["Country"] == "Senegal", :]
Senegal_Aid_df=Senegal_Aid_df[["Year","Total Aid"]]
Senegal_Aid_plot=Senegal_Aid_df.set_index("Year")
Sierra_Leone_Aid_df = Aid_df.loc[Aid_df["Country"] == "Sierra Leone", :]
Sierra_Leone_Aid_df=Sierra_Leone_Aid_df[["Year","Total Aid"]]
Sierra_Leone_Aid_plot=Sierra_Leone_Aid_df.set_index("Year")
Somalia_Aid_df = Aid_df.loc[Aid_df["Country"] == "Somalia", :]
Somalia_Aid_df=Somalia_Aid_df[["Year","Total Aid"]]
Somalia_Aid_plot=Somalia_Aid_df.set_index("Year")
South_Africa_Aid_df = Aid_df.loc[Aid_df["Country"] == "South Africa", :]
South_Africa_Aid_df=South_Africa_Aid_df[["Year","Total Aid"]]
South_Africa_Aid_plot=South_Africa_Aid_df.set_index("Year")
Uganda_Aid_df = Aid_df.loc[Aid_df["Country"] == "Uganda", :]
Uganda_Aid_df=Uganda_Aid_df[["Year","Total Aid"]]
Uganda_Aid_plot=Uganda_Aid_df.set_index("Year")

Zimbabwe_Aid_df = Aid_df.loc[Aid_df["Country"] == "Zimbabwe", :]
Zimbabwe_Aid_df=Zimbabwe_Aid_df[["Year","Total Aid"]]
Zimbabwe_Aid_plot=Zimbabwe_Aid_df.set_index("Year")

# %%
Benin_chart =Benin_Country_plot_df.plot(kind='bar')
Benin_chart.set_xlabel("Year")
Benin_chart.set_ylabel("GDP (in Hundred Billions)")
Benin_Aid_chart=Benin_Aid_plot.plot.line()
Benin_Aid_chart.set_xlabel("Year")
Benin_Aid_chart.set_ylabel("Total Aid")

plt.show()

# %%
Burundi_chart =Burundi_Country_plot_df.plot(kind='bar')
Burundi_chart.set_xlabel("Year")
Burundi_chart.set_ylabel("GDP (in Hundred Billions)")

Burundi_Aid_chart=Burundi_Aid_plot.plot.line()
Burundi_Aid_chart.set_xlabel("Year")
Burundi_Aid_chart.set_ylabel("Total Aid")
plt.show()

# %%
Ethiopia_chart =Ethiopia_Country_plot_df.plot(kind='bar')
Ethiopia_chart.set_xlabel("Year")
Ethiopia_chart.set_ylabel("GDP (in Hundred Billions)")

Ethiopia_Aid_chart=Ethiopia_Aid_plot.plot.line()
Ethiopia_Aid_chart.set_xlabel("Year")
Ethiopia_Aid_chart.set_ylabel("Total Aid")
plt.show()

# %%
Ghana_chart =Ghana_Country_plot_df.plot(kind='bar')
Ghana_chart.set_xlabel("Year")
Ghana_chart.set_ylabel("GDP (in Hundred Billions)")


Ghana_Aid_chart=Ghana_Aid_plot.plot.line()
Ghana_Aid_chart.set_xlabel("Year")
Ghana_Aid_chart.set_ylabel("Total Aid")
plt.show()

# %%
Kenya_chart =Kenya_Country_plot_df.plot(kind='bar')
Kenya_chart.set_xlabel("Year")
Kenya_chart.set_ylabel("GDP (in Hundred Billions)")
Kenya_Aid_chart=Kenya_Aid_plot.plot.line()
Kenya_Aid_chart.set_xlabel("Year")
Kenya_Aid_chart.set_ylabel("Total Aid")

plt.show()

# %%
Madagascar_chart =Madagascar_Country_plot_df.plot(kind='bar')
Madagascar_chart.set_xlabel("Year")
Madagascar_chart.set_ylabel("GDP (in Hundred Billions)")
Madagascar_Aid_chart=Madagascar_Aid_plot.plot.line()
Madagascar_Aid_chart.set_xlabel("Year")
Madagascar_Aid_chart.set_ylabel("Total Aid")

plt.show()

# %%
Mali_chart =Mali_Country_plot_df.plot(kind='bar')
Mali_chart.set_xlabel("Year")
Mali_chart.set_ylabel("GDP (in Hundred Billions)")
Mali_Aid_chart=Mali_Aid_plot.plot.line()
Mali_Aid_chart.set_xlabel("Year")
Mali_Aid_chart.set_ylabel("Total Aid")


plt.show()

# %%
Mozambique_chart =Mozambique_Country_plot_df.plot(kind='bar')
Mozambique_chart.set_xlabel("Year")
Mozambique_chart.set_ylabel("GDP (in Hundred Billions)")
Mozambique_Aid_chart=Mozambique_Aid_plot.plot.line()
Mozambique_Aid_chart.set_xlabel("Year")
Mozambique_Aid_chart.set_ylabel("Total Aid")


plt.show()

# %%
Namibia_chart =Namibia_Country_plot_df.plot(kind='bar')
Namibia_chart.set_xlabel("Year")
Namibia_chart.set_ylabel("GDP (in Hundred Billions)")
Namibia_Aid_chart=Namibia_Aid_plot.plot.line()
Namibia_Aid_chart.set_xlabel("Year")
Namibia_Aid_chart.set_ylabel("Total Aid")

plt.show()

# %%
Nigeria_chart =Nigeria_Country_plot_df.plot(kind='bar')
Nigeria_chart.set_xlabel("Year")
Nigeria_chart.set_ylabel("GDP (in Hundred Billions)")
Nigeria_Aid_chart=Nigeria_Aid_plot.plot.line()
Nigeria_Aid_chart.set_xlabel("Year")
Nigeria_Aid_chart.set_ylabel("Total Aid")

plt.show()

# %%
Rwanda_chart =Rwanda_Country_plot_df.plot(kind='bar')
Rwanda_chart.set_xlabel("Year")
Rwanda_chart.set_ylabel("GDP (in Hundred Billions)")
Rwanda_Aid_chart=Rwanda_Aid_plot.plot.line()
Rwanda_Aid_chart.set_xlabel("Year")
Rwanda_Aid_chart.set_ylabel("Total Aid")

plt.show()

# %%
Senegal_chart =Senegal_Country_plot_df.plot(kind='bar')
Senegal_chart.set_xlabel("Year")
Senegal_chart.set_ylabel("GDP (in Hundred Billions)")
Senegal_Aid_chart=Senegal_Aid_plot.plot.line()
Senegal_Aid_chart.set_xlabel("Year")
Senegal_Aid_chart.set_ylabel("Total Aid")

plt.show()

# %%
Sierra_Leone_chart =Sierra_Leone_Country_plot_df.plot(kind='bar')
Sierra_Leone_chart.set_xlabel("Year")
Sierra_Leone_chart.set_ylabel("GDP (in Hundred Billions)")
Sierra_Leone_Aid_chart=Sierra_Leone_Aid_plot.plot.line()
Sierra_Leone_Aid_chart.set_xlabel("Year")
Sierra_Leone_Aid_chart.set_ylabel("Total Aid")



plt.show()

# %%
Somalia_chart =Somalia_Country_plot_df.plot(kind='bar')
Somalia_chart.set_xlabel("Year")
Somalia_chart.set_ylabel("GDP (in Hundred Billions)")
Somalia_Aid_chart=Somalia_Aid_plot.plot.line()
Somalia_Aid_chart.set_xlabel("Year")
Somalia_Aid_chart.set_ylabel("Total Aid")

plt.show()

# %%
South_Africa_chart =South_Africa_Country_plot_df.plot(kind='bar')

South_Africa_chart.set_xlabel("Year")
South_Africa_chart.set_ylabel("GDP (in Hundred Billions)")
South_Africa_Aid_chart=South_Africa_Aid_plot.plot.line()
South_Africa_Aid_chart.set_xlabel("Year")
South_Africa_Aid_chart.set_ylabel("Total Aid")


plt.show()

# %%
Uganda_chart =Uganda_Country_plot_df.plot(kind='bar')
Uganda_chart.set_xlabel("Year")
Uganda_chart.set_ylabel("GDP (in Hundred Billions)")
Uganda_Aid_chart=Uganda_Aid_plot.plot.line()
Uganda_Aid_chart.set_xlabel("Year")
Uganda_Aid_chart.set_ylabel("Total Aid")


plt.show()

# %%
Zimbabwe_chart =Zimbabwe_Country_plot_df.plot(kind='bar')
Zimbabwe_chart.set_xlabel("Year")
Zimbabwe_chart.set_ylabel("GDP (in Hundred Billions)")
Zimbabwe_Aid_chart=Zimbabwe_Aid_plot.plot.line()
Zimbabwe_Aid_chart.set_xlabel("Year")
Zimbabwe_Aid_chart.set_ylabel("Total Aid")


plt.show()

# %%
GDP_renamed_df
# Out:
#       Country  Year           GDP
# 0      Angola  2002  1.528559e+10
# 1      Angola  2003  1.781271e+10
# 2      Angola  2004  2.355205e+10
# 3      Angola  2005  3.697092e+10
# 4      Angola  2006  5.238101e+10
# 5      Angola  2007  6.526645e+10
# 6      Angola  2008  8.853861e+10
# 7      Angola  2009  7.030716e+10
# 8      Angola  2010  8.379950e+10
# 9      Angola  2011  1.117897e+11
# 10     Angola  2012  1.280529e+11
# 11     Angola  2013  1.367099e+11
# 12     Angola  2014  1.457122e+11
# 13     Angola  2015  1.161936e+11
# 14     Angola  2016  1.011239e+11
# 15     Angola  2017  1.221238e+11
# 16      Benin  2002  3.054571e+09
# 17      Benin  2003  3.905366e+09
# 18      Benin  2004  4.521425e+09
# 19      Benin  2005  4.803703e+09
# 20      Benin  2006  5.142381e+09
# 21      Benin  2007  5.969535e+09
# 22      Benin  2008  7.132787e+09
# 23      Benin  2009  7.097199e+09
# 24      Benin  2010  6.970241e+09
# 25      Benin  2011  7.814081e+09
# ...

# %%
grouped_year_df = GDP_renamed_df.groupby(['Year'])
print(grouped_year_df)

# %%
GDP_year_mean_df=grouped_year_df["GDP"].mean()
GDP_year_mean_df
# Out:
# Year
# 2002    1.644826e+10
# 2003    2.102642e+10
# 2004    2.665186e+10
# 2005    3.193472e+10
# 2006    3.826965e+10
# 2007    4.419416e+10
# 2008    4.970558e+10
# 2009    4.738158e+10
# 2010    5.729274e+10
# 2011    6.511887e+10
# 2012    6.943007e+10
# 2013    7.390051e+10
# 2014    7.715782e+10
# 2015    6.948083e+10
# 2016    6.335415e+10
# 2017    6.786372e+10
# Name: GDP, dtype: float64

# %%
GDP_year_mean_chart =GDP_year_mean_df.plot(kind='bar')
GDP_year_mean_chart.set_xlabel("Year")
GDP_year_mean_chart.set_ylabel("GDP(mean) (in Hundred Billions)")
plt.show()
